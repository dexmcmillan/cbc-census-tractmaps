# %% [markdown]
# # StatsCan shapefile processing
# *April 22, 2022*

# %% [markdown]
# This notebook takes statscan census shapefiles and processes them into various useful maps for import into Datawrapper. First, we import geopandas, pandas, and a third module to suppress some annoying warning messages.

# %%
import geopandas
import pandas as pd
import warnings;   warnings.filterwarnings("ignore")

# %% [markdown]
# Now we read in the latest StatsCan census boundary files, and convert the coordinate system to EPSG:4326, which is what Datawrapper likes.

# %%
tracts = (geopandas
          .read_file("https://www12.statcan.gc.ca/census-recensement/2021/geo/sip-pis/boundary-limites/files-fichiers/lcma000b21a_e.zip")
          .to_crs("EPSG:4326")
          )

# %% [markdown]
# Next, we read in a table that contains pre-prepared info: a list of provinces that match to PRUIDs, and a list of CMAs that matches names of CMAs and CAs to DGUIDs.

# %%
province_list = pd.read_csv("./data/provinces.csv").astype(str).set_index("PRUID")
cma_list = pd.read_csv("./data/cmas.csv").astype(str).set_index("ID")

# %% [markdown]
# Let's take a peek at the tracts table.

# %%
tracts.sample(20)
# Out:
#            CTUID                DGUID   CTNAME  LANDAREA PRUID  \
# 4664  9330228.03  2021S05079330228.03  0228.03    0.3275    59
# 2011  9330038.00  2021S05079330038.00  0038.00    0.5890    59
# 476   4620257.00  2021S05074620257.00  0257.00    1.3088    24
# 683   8250206.07  2021S05078250206.07  0206.07    2.4784    48
# 1040  5350162.00  2021S05075350162.00  0162.00    0.5757    35
# 2365  5320202.16  2021S05075320202.16  0202.16   60.7246    35
# 5831  5350620.23  2021S05075350620.23  0620.23    2.7492    35
# 2348  5410110.00  2021S05075410110.00  0110.00   99.6579    35
# 3137  5370217.02  2021S05075370217.02  0217.02    2.1841    35
# 2553  4210700.00  2021S05074210700.00  0700.00   44.5657    24
# 2769  4620661.01  2021S05074620661.01  0661.01    5.6006    24
# 466   4620247.00  2021S05074620247.00  0247.00    0.1931    24
# 1255  5350605.00  2021S05075350605.00  0605.00    1.5287    35
# 169   3100131.02  2021S05073100131.02  0131.02  631.3491    13
# 3107  5370001.01  2021S05075370001.01  0001.01    5.5072    35
# 2729  4620324.02  2021S05074620324.02  0324.02    0.6745    24
# 898   8350006.13  2021S05078350006.13  0006.13    2.7196    48
# 896   8350004.01  2021S05078350004.01  0004.01    1.9341    48
# 5841  5350610.06  2021S05075350610.06  0610.06    1.4267    35
# 4501  4622206.00  2021S05074622206.00  2206.00   26.6505    24
#
#                                                geometry
# 4664  POLYGON ((-123.01329 49.23275, -123.01262 49.2...
# 2011  POLYGON ((-123.08980 49.25669, -123.08985 49.2...
# 476   POLYGON ((-73.60917 45.56420, -73.60950 45.563...
# 683   POLYGON ((-114.01340 51.28668, -114.01339 51.2...
# 1040  POLYGON ((-79.44502 43.68579, -79.44611 43.685...
# 2365  POLYGON ((-78.64099 43.94428, -78.63453 43.929...
# 5831  POLYGON ((-79.86711 43.48642, -79.86650 43.486...
# 2348  POLYGON ((-80.36974 43.55394, -80.36977 43.552...
# 3137  POLYGON ((-79.77663 43.34630, -79.77742 43.345...
# 2553  POLYGON ((-70.95024 46.85450, -70.93067 46.840...
# 2769  MULTIPOLYGON (((-73.77511 45.63901, -73.77519 ...
# 466   POLYGON ((-73.60963 45.53960, -73.60999 45.539...
# 1255  POLYGON ((-79.66626 43.44006, -79.66597 43.439...
# 169   MULTIPOLYGON (((-65.53038 45.32353, -65.53053 ...
# 3107  POLYGON ((-79.80565 43.20284, -79.80662 43.200...
# 2729  POLYGON ((-73.62893 45.42052, -73.62909 45.420...
# 898   POLYGON ((-113.63041 53.52907, -113.63032 53.5...
# 896   POLYGON ((-113.55907 53.49703, -113.55892 53.4...
# 5841  POLYGON ((-79.70919 43.39323, -79.70920 43.393...
# 4501  POLYGON ((-73.28877 45.37610, -73.29113 45.375...

# %% [markdown]
# First, we want to simplify our polygons a bit. Datawrapper has an upload size limit of 2MB, so we use `.simplify()` to reduce the size to an acceptable level.

# %%
simple_tracts = tracts.copy()

simple_tracts["geometry"] = tracts["geometry"].simplify(tolerance=0.0001)

# %% [markdown]
# Now, we iterate through every CMA and CA in our list, and match that DGUID to the one in our shapefiles. Then, if there's data for that CMA, we output the file as a GeoJSON.

# %%
for id in cma_list.index.unique():
    
    name = cma_list.at[id, "NAME"].strip().lower().replace(" ", "")
    id_trim = id[-3:]
    
    data = (simple_tracts
           .loc[simple_tracts["DGUID"].str.contains("2021S0507" + id_trim, regex=True), :]
          )
    
    if len(data) > 0:
          data.to_file(f"./data/cities/{name}.geojson", driver='GeoJSON')

# %% [markdown]
# That's all. Now the repo should be populated with a list of useable GeoJSON files for Datawrapper maps based on the most recent data.
#
# \-30\-
